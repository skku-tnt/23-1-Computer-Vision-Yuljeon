# %%
import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader
import torch.optim as optim

from unet import UNet
from dataset import SegmentationDataset

# %%
# Define the data transforms
transform = transforms.Compose([
    transforms.ToTensor(),         # Convert the images to PyTorch tensors
    transforms.Grayscale()
])

# %%
# Define the data directories
data_dir = './data'
train_dir = data_dir + '/train'
test_dir = data_dir + '/test'
val_dir = data_dir + '/val'

# %%
# Load the datasets
train_data = SegmentationDataset(train_dir, transform=transform)
test_data = SegmentationDataset(test_dir, transform=transform)
val_data = SegmentationDataset(val_dir, transform=transform)

# Create data loaders
train_loader = DataLoader(train_data, batch_size=8, shuffle=True)
test_loader = DataLoader(test_data, batch_size=8)
val_loader = DataLoader(val_data, batch_size=8)

# %%
# Load the pre-trained ResNet50 model
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = UNet(n_channels=1, n_classes=1).to(device)

# %%
# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.002, weight_decay=0.0001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.1)

# %%
# Define the validation function
def validate(model, testloader, criterion, device):
    model.eval()
    total_dice_coeff = 0
    total_loss = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data[0].to(device), data[1].to(device)
            outputs = model(images)
            loss = criterion(outputs.squeeze(1), labels.squeeze(1))
            total_loss += loss.item()
            dice_coeff = dice_coefficient(outputs, labels)
            total_dice_coeff += dice_coeff.item()
            
    val_loss = total_loss
    val_dice_coeff = total_dice_coeff / len(testloader) * 100
    return val_dice_coeff, val_loss

def dice_coefficient(outputs, labels):
    smooth = 1.
    num = outputs.size(0)
    outputs = outputs.view(num, -1)
    labels = labels.view(num, -1)
    intersection = (outputs * labels).sum(1)
    dice = (2. * intersection + smooth) / (outputs.sum(1) + labels.sum(1) + smooth)
    return dice.mean()

# %%
best_loss = float('inf')
patience = 15
counter = 0

# Train the model
for epoch in range(200):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs.squeeze(1), labels.squeeze(1))
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    # Validate the model every 1 epoch
    if (epoch + 1) % 1 == 0:
        val_accuracy, val_loss = validate(model, val_loader, criterion, device)
        print(f'Epoch {epoch + 1}, Loss {running_loss / len(train_loader):.4f}, Validation Loss {val_loss:.4f}, Validation Accuracy {val_accuracy:.2f}%')
        running_loss = 0.0

        if val_loss < best_loss:
            best_loss = val_loss
            model_name = f'models/unet_best_epoch.pth'
            torch.save(model.state_dict(), model_name)
            counter = 0

        else:
            counter += 1
            if counter >= patience:
                print(f'Validation loss did not improve for {patience} epochs, stopping training')
                break
# Out:
# Epoch 1, Loss 1105.4352, Validation Loss 2249.5673, Validation Accuracy 56.12%
# Epoch 2, Loss 1955.6062, Validation Loss 2235.2441, Validation Accuracy 74.32%
# Epoch 3, Loss 1099.8966, Validation Loss 2233.0930, Validation Accuracy 1.06%
# Epoch 4, Loss 1098.4537, Validation Loss 2231.1566, Validation Accuracy 49.74%
# Epoch 5, Loss 1097.8810, Validation Loss 2230.1912, Validation Accuracy 40.43%
# Epoch 6, Loss 1097.4888, Validation Loss 2229.2991, Validation Accuracy 36.03%
# Epoch 7, Loss 1097.0534, Validation Loss 2227.8453, Validation Accuracy 35.14%
# Epoch 8, Loss 1096.3098, Validation Loss 2229.0775, Validation Accuracy -164.67%
# Epoch 9, Loss 1095.2589, Validation Loss 2223.8154, Validation Accuracy 62.43%
# Epoch 10, Loss 1094.2521, Validation Loss 2222.1034, Validation Accuracy 67.01%
# Epoch 11, Loss 1093.3228, Validation Loss 2226.1320, Validation Accuracy 70.16%
# Epoch 12, Loss 1093.6902, Validation Loss 2222.8967, Validation Accuracy 71.80%
# Epoch 13, Loss 1092.9665, Validation Loss 2220.4954, Validation Accuracy 61.95%
# Epoch 14, Loss 1092.0846, Validation Loss 2220.8861, Validation Accuracy 75.89%
# Epoch 15, Loss 1091.9466, Validation Loss 2220.5166, Validation Accuracy 79.62%
# Epoch 16, Loss 1091.6358, Validation Loss 2218.6516, Validation Accuracy 78.98%
# Epoch 17, Loss 1091.6144, Validation Loss 2218.8267, Validation Accuracy 79.54%
# Epoch 18, Loss 1091.0553, Validation Loss 2218.4539, Validation Accuracy 78.71%
# Epoch 19, Loss 1091.5585, Validation Loss 2222.4058, Validation Accuracy 80.58%
# Epoch 20, Loss 1091.3957, Validation Loss 2218.2275, Validation Accuracy 69.49%
# Epoch 21, Loss 1090.7398, Validation Loss 2218.1218, Validation Accuracy 76.87%
# Epoch 22, Loss 1090.6535, Validation Loss 2217.3326, Validation Accuracy 76.22%
# Epoch 23, Loss 1090.2512, Validation Loss 2217.8273, Validation Accuracy 77.32%
# Epoch 24, Loss 1089.9719, Validation Loss 2216.5742, Validation Accuracy 79.65%
# Epoch 25, Loss 1090.0255, Validation Loss 2217.8577, Validation Accuracy 84.20%
# Epoch 26, Loss 1090.1096, Validation Loss 2215.9890, Validation Accuracy 81.06%
# Epoch 27, Loss 1090.4422, Validation Loss 2217.9124, Validation Accuracy 84.33%
# Epoch 28, Loss 1090.4673, Validation Loss 2219.3160, Validation Accuracy 73.23%
# Epoch 29, Loss 1091.1976, Validation Loss 2216.8091, Validation Accuracy 77.45%
# Epoch 30, Loss 1090.3113, Validation Loss 2219.1198, Validation Accuracy 76.11%
# Epoch 31, Loss 1089.4065, Validation Loss 2215.3627, Validation Accuracy 72.52%
# Epoch 32, Loss 1089.0172, Validation Loss 2214.4561, Validation Accuracy 77.84%
# Epoch 33, Loss 1088.9266, Validation Loss 2214.1251, Validation Accuracy 81.49%
# Epoch 34, Loss 1088.7568, Validation Loss 2214.1772, Validation Accuracy 78.64%
# Epoch 35, Loss 1088.4159, Validation Loss 2213.1749, Validation Accuracy 83.53%
# Epoch 36, Loss 1088.3755, Validation Loss 2212.7726, Validation Accuracy 83.60%
# Epoch 37, Loss 1088.1434, Validation Loss 2213.8038, Validation Accuracy 84.08%
# Epoch 38, Loss 1088.0842, Validation Loss 2213.7729, Validation Accuracy 87.56%
# Epoch 39, Loss 1087.8378, Validation Loss 2212.2628, Validation Accuracy 86.47%
# Epoch 40, Loss 1087.6768, Validation Loss 2213.3260, Validation Accuracy 82.81%
# Epoch 41, Loss 1087.4841, Validation Loss 2210.7899, Validation Accuracy 86.19%
# Epoch 42, Loss 1087.6623, Validation Loss 2211.1094, Validation Accuracy 88.78%
# Epoch 43, Loss 1086.9393, Validation Loss 2210.1030, Validation Accuracy 86.41%
# Epoch 44, Loss 1086.5272, Validation Loss 2210.4722, Validation Accuracy 85.54%
# Epoch 45, Loss 1086.1863, Validation Loss 2210.6554, Validation Accuracy 84.53%
# Epoch 46, Loss 1086.4721, Validation Loss 2209.6094, Validation Accuracy 86.89%
# Epoch 47, Loss 1086.4283, Validation Loss 2210.4525, Validation Accuracy 93.48%
# Epoch 48, Loss 1085.8429, Validation Loss 2210.1267, Validation Accuracy 87.25%
# Epoch 49, Loss 1085.6816, Validation Loss 2208.3577, Validation Accuracy 84.25%
# Epoch 50, Loss 1085.6570, Validation Loss 2208.9877, Validation Accuracy 89.55%
# Epoch 51, Loss 1085.2663, Validation Loss 2209.4794, Validation Accuracy 89.28%
# Epoch 52, Loss 1085.0845, Validation Loss 2209.5825, Validation Accuracy 94.36%
# Epoch 53, Loss 1085.2486, Validation Loss 2206.9152, Validation Accuracy 83.02%
# Epoch 54, Loss 1084.5839, Validation Loss 2207.9486, Validation Accuracy 91.10%
# Epoch 55, Loss 1084.8968, Validation Loss 2208.1890, Validation Accuracy 92.31%
# Epoch 56, Loss 1084.5844, Validation Loss 2206.6345, Validation Accuracy 86.75%
# Epoch 57, Loss 1084.4906, Validation Loss 2207.1377, Validation Accuracy 89.77%
# Epoch 58, Loss 1083.9833, Validation Loss 2206.7866, Validation Accuracy 88.77%
# Epoch 59, Loss 1084.1663, Validation Loss 2206.7490, Validation Accuracy 86.48%
# Epoch 60, Loss 1084.1972, Validation Loss 2206.9508, Validation Accuracy 91.19%
# Epoch 61, Loss 1083.7127, Validation Loss 2207.1329, Validation Accuracy 86.85%
# Epoch 62, Loss 1083.5642, Validation Loss 2208.0138, Validation Accuracy 89.05%
# Epoch 63, Loss 1083.3671, Validation Loss 2207.2687, Validation Accuracy 85.32%
# Epoch 64, Loss 1083.3487, Validation Loss 2206.5887, Validation Accuracy 87.60%
# Epoch 65, Loss 1083.2522, Validation Loss 2209.2783, Validation Accuracy 93.62%
# Epoch 66, Loss 1083.3020, Validation Loss 2209.5044, Validation Accuracy 89.06%
# Epoch 67, Loss 1083.3538, Validation Loss 2207.3474, Validation Accuracy 90.18%
# Epoch 68, Loss 1082.8030, Validation Loss 2207.4525, Validation Accuracy 88.70%
# Epoch 69, Loss 1082.8002, Validation Loss 2206.7657, Validation Accuracy 86.67%
# Epoch 70, Loss 1082.9024, Validation Loss 2206.7972, Validation Accuracy 89.28%
# Epoch 71, Loss 1082.6885, Validation Loss 2207.1348, Validation Accuracy 89.50%
# Epoch 72, Loss 1082.8391, Validation Loss 2205.9387, Validation Accuracy 86.62%
# Epoch 73, Loss 1082.0590, Validation Loss 2207.9452, Validation Accuracy 82.96%
# Epoch 74, Loss 1081.9583, Validation Loss 2207.4642, Validation Accuracy 83.42%
# Epoch 75, Loss 1082.0858, Validation Loss 2207.6447, Validation Accuracy 88.31%
# Epoch 76, Loss 1082.0506, Validation Loss 2207.7045, Validation Accuracy 89.86%
# Epoch 77, Loss 1081.8542, Validation Loss 2206.8737, Validation Accuracy 87.99%
# Epoch 78, Loss 1081.5833, Validation Loss 2207.3514, Validation Accuracy 84.22%
# Epoch 79, Loss 1081.5095, Validation Loss 2208.1100, Validation Accuracy 88.46%
# Epoch 80, Loss 1081.0044, Validation Loss 2210.0734, Validation Accuracy 86.45%
# Epoch 81, Loss 1081.2031, Validation Loss 2211.5833, Validation Accuracy 99.37%
# Epoch 82, Loss 1080.6460, Validation Loss 2211.4460, Validation Accuracy 86.64%
# Epoch 83, Loss 1080.4813, Validation Loss 2208.6774, Validation Accuracy 82.67%
# Epoch 84, Loss 1080.0946, Validation Loss 2208.4185, Validation Accuracy 84.48%
# Epoch 85, Loss 1080.5894, Validation Loss 2210.3794, Validation Accuracy 84.96%
# Epoch 86, Loss 1080.3335, Validation Loss 2209.9425, Validation Accuracy 91.40%
# Epoch 87, Loss 1080.1085, Validation Loss 2212.4822, Validation Accuracy 87.70%
# Validation loss did not improve for 15 epochs, stopping training
